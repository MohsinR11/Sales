# %% [markdown]
# # **🧠 AI-powered portfolio project**

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### **📦 Import Libraries & Load Data**

# %%
# 📦 Importing essential libraries for data analysis and visualization
import pandas as pd                # For data manipulation and analysis
import numpy as np                 # For numerical operations (optional in this snippet)
import seaborn as sns              # For advanced data visualizations
import matplotlib.pyplot as plt    # For basic plotting

# 📥 Load the sales dataset from a CSV file into a DataFrame
df = pd.read_csv("sales.csv")     # Replace "sales.csv" with the full file path if needed

# 🕒 Convert the 'Date' column to datetime format to enable time-based operations
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# 👀 Display the first 5 rows of the dataset to get a quick overview
df.head()
# Out:
#    OrderID   Product         Category  Revenue  Profit       Date   Region  \
# 0     2001   Printer  Office Supplies      736  119.55 2023-07-18    North
# 1     2002   Monitor      Electronics     1007  149.83 2024-10-17    North
# 2     2003  Keyboard      Accessories      612  172.38 2022-04-06     West
# 3     2004   Printer  Office Supplies     1949  451.81 2023-04-30     East
# 4     2005    Tablet      Electronics     1640  215.88 2022-08-19  Central
#
#    Quantity
# 0         6
# 1         8
# 2         1
# 3         7
# 4         9

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### **📋 Basic Info & Preprocessing**

# %%
# 📊 OVERVIEW OF THE DATAFRAME

# 🔎 Check the structure and data types of each column
print(df.info())  # Shows non-null counts, data types, and memory usage

# 📈 Get basic statistical details for numeric columns
print(df.describe())  # Includes mean, std, min, max, etc.

# 🧹 Check for missing values in each column
print(df.isnull().sum())  # Helps identify if any column has null/missing data


# 🧽 DATA CLEANING

# 🔁 Remove duplicate rows, if any, to ensure data quality
df.drop_duplicates(inplace=True)


# 📅 FEATURE ENGINEERING — Extracting useful time-based features

# 📆 Extract year from the 'Date' column
df['Year'] = df['Date'].dt.year

# 🗓️ Extract full month name (e.g., January, February)
df['Month'] = df['Date'].dt.month_name()

# 🔢 Extract day of the month
df['Day'] = df['Date'].dt.day

# 📅 Extract the weekday name (e.g., Monday, Tuesday)
df['Weekday'] = df['Date'].dt.day_name()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OrderID   58 non-null     int64
#  1   Product   58 non-null     object
#  2   Category  58 non-null     object
#  3   Revenue   58 non-null     int64
#  4   Profit    58 non-null     float64
#  5   Date      58 non-null     datetime64[ns]
#  6   Region    58 non-null     object
#  7   Quantity  58 non-null     int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 3.8+ KB
# None
#            OrderID      Revenue      Profit                           Date  \
# count    58.000000    58.000000   58.000000                             58
# mean   2029.500000  1024.810345  190.043793  2023-07-22 19:26:53.793103360
# min    2001.000000    63.000000    9.370000            2022-01-02 00:00:00
# 25%    2015.250000   623.750000   77.997500            2022-10-10 12:00:00
# ...

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### **📊 Univariate Analysis**

# %% [markdown]
# #### **🔹 Revenue Distribution**

# %%
# 📊 DATA VISUALIZATION - REVENUE DISTRIBUTION

# 🖼️ Set the figure size for the plot (width: 11, height: 5)
plt.figure(figsize=(11, 5))

# 📈 Create a histogram with a KDE (Kernel Density Estimate) for the 'Revenue' column
sns.histplot(df['Revenue'], color='deepskyblue', kde=True)

# 🏷️ Set the title of the plot to describe what we're visualizing
plt.title("Revenue Distribution")

# 🚫 Disable the grid lines for a cleaner plot
plt.grid(False)

# 🖼️ Display the plot
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### **🔹 Profit Distribution**

# %%
# 📊 DATA VISUALIZATION - PROFIT DISTRIBUTION

# 🖼️ Set the figure size for the plot (width: 11, height: 5)
plt.figure(figsize=(11, 5))

# 📈 Create a histogram with a KDE (Kernel Density Estimate) for the 'Profit' column
sns.histplot(df['Profit'], kde=True, color='lime')

# 🏷️ Set the title of the plot to describe what we're visualizing
plt.title("Profit Distribution")

# 🚫 Disable the grid lines for a cleaner plot
plt.grid(False)

# 🖼️ Display the plot
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### **🔹 Quantity Sold**

# %%
# 📊 DATA VISUALIZATION - QUANTITY COUNT

# 🖼️ Set the figure size for the plot (width: 11, height: 5)
plt.figure(figsize=(11, 5))

# 📊 Create a countplot to visualize the frequency of each unique 'Quantity' value in the dataset
sns.countplot(x='Quantity', data=df, palette='pastel')

# 🏷️ Set the title of the plot to describe what we're visualizing
plt.title("Quantity Count")

# 🚫 Disable the grid lines for a cleaner plot
plt.grid(False)

# 🖼️ Display the plot
plt.show()
# Out:
# C:\Users\mohsi\AppData\Local\Temp\ipykernel_17392\3737059994.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Quantity', data=df, palette='pastel')

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### **📈 4. Bivariate Analysis (Correlations)**

# %% [markdown]
# #### **🔹 Revenue vs Profit**

# %%
# 📊 DATA VISUALIZATION - REVENUE vs PROFIT (BY CATEGORY)

# 🖼️ Set the figure size for the plot (width: 11, height: 5)
plt.figure(figsize=(11, 5))

# 🔵 Create a scatter plot to show the relationship between 'Revenue' and 'Profit'
# 'hue' is used to color points by 'Category' and 's' adjusts the size of the points
sns.scatterplot(x='Revenue', y='Profit', data=df, hue='Category', s=140)

# 🏷️ Set the title of the plot to describe what we're visualizing
plt.title("Revenue vs Profit (by Category)")

# 🚫 Disable the grid lines for a cleaner plot
plt.grid(False)

# 🖼️ Display the plot
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### **🔹 Correlation Matrix**

# %%
# 📊 DATA VISUALIZATION - CORRELATION HEATMAP

# 🔍 Calculate the correlation matrix for the 'Revenue', 'Profit', and 'Quantity' columns
corr = df[['Revenue', 'Profit', 'Quantity']].corr()

# 🖼️ Set the figure size for the plot (width: 11, height: 5)
plt.figure(figsize=(11, 5))

# 🌡️ Create a heatmap to visualize the correlation between the selected columns
# 'annot=True' displays the correlation values on the heatmap, and 'cmap' defines the color scheme
sns.heatmap(corr, annot=True, cmap='PuRd')

# 🏷️ Set the title of the heatmap to describe what we're visualizing
plt.title("Correlation Heatmap")

# 🖼️ Display the heatmap plot
plt.show()

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### **🕰️ Time Series Trends**

# %% [markdown]
# #### **🔹 Monthly Revenue Trend**

# %%
# 📊 DATA VISUALIZATION - MONTHLY REVENUE TREND

# 🔢 Group the data by 'Year' and 'Month' to calculate the total revenue for each month
# Use 'sum()' to aggregate the revenue per group, and reset the index to create a clean DataFrame
monthly_rev = df.groupby(['Year', 'Month'])['Revenue'].sum().reset_index()

# 📅 Create a 'Date' column by combining the 'Year' and 'Month' columns and converting it to datetime format
monthly_rev['Date'] = pd.to_datetime(monthly_rev['Year'].astype(str) + '-' + monthly_rev['Month'].astype(str))

# 🖼️ Set the figure size for the plot (width: 11, height: 5)
plt.figure(figsize=(11, 5))

# 📈 Create a line plot to visualize the monthly revenue trend over time
# 'sort_values' ensures the dates are ordered correctly on the x-axis
sns.lineplot(data=monthly_rev.sort_values('Date'), x='Date', y='Revenue', color='red')

# 🏷️ Set the title of the plot to describe what we're visualizing
plt.title("Monthly Revenue Trend")

# 🚫 Disable the grid lines for a cleaner plot
plt.grid(False)

# 🖼️ Display the plot
plt.show()
# Out:
# C:\Users\mohsi\AppData\Local\Temp\ipykernel_17392\2566748317.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   monthly_rev['Date'] = pd.to_datetime(monthly_rev['Year'].astype(str) + '-' + monthly_rev['Month'].astype(str))

# %% [markdown]
# ---

# %% [markdown]
# #### **🔹 Profit by Region**

# %%
# 📊 DATA VISUALIZATION - TOTAL PROFIT BY REGION

# 🖼️ Set the figure size for the plot (width: 11, height: 5)
plt.figure(figsize=(11, 5))

# 📊 Create a bar plot to visualize the total profit by region
# Group data by 'Region' and calculate the sum of 'Profit' for each region using 'groupby()' and 'sum()'
# Reset the index to make the DataFrame clean for plotting
sns.barplot(data=df.groupby('Region')['Profit'].sum().reset_index(),
            x='Region',        # Set 'Region' as the x-axis
            y='Profit',        # Set 'Profit' as the y-axis
            color='lime',      # Set the color of the bars
            width=0.6,         # Adjust the width of the bars
            estimator=sum,     # Use 'sum' as the estimator to aggregate profits per region
            errorbar=None,     # Remove error bars from the plot
            palette='Set2')    # Use the 'Set2' color palette for the bars

# 🏷️ Set the title of the plot to describe what we're visualizing
plt.title("Total Profit by Region")

# 🔄 Rotate the x-axis labels (region names) for better readability
plt.xticks(rotation=45)

# 🚫 Disable the grid lines for a cleaner plot
plt.grid(False)

# 🖼️ Display the plot
plt.show()
# Out:
# C:\Users\mohsi\AppData\Local\Temp\ipykernel_17392\1951614133.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df.groupby('Region')['Profit'].sum().reset_index(),

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### **🚨 Outlier Detection**

# %% [markdown]
# #### **🔹 Revenue & Profit Boxplots**

# %%
# 📊 DATA VISUALIZATION - REVENUE AND PROFIT OUTLIERS

# 🖼️ Create a figure with 1 row and 2 columns of subplots, with a total figure size of (width: 11, height: 5)
fig, axes = plt.subplots(1, 2, figsize=(11, 5))

# 📦 Create a boxplot for the 'Revenue' column to visualize outliers
# The boxplot is drawn on the first subplot (axes[0]) and colored red
sns.boxplot(ax=axes[0], y=df['Revenue'], color='red')

# 🏷️ Set the title for the first subplot (Revenue outliers)
axes[0].set_title("Revenue Outliers")

# 📦 Create a boxplot for the 'Profit' column to visualize outliers
# The boxplot is drawn on the second subplot (axes[1]) and colored aqua
sns.boxplot(ax=axes[1], y=df['Profit'], color='aqua')

# 🏷️ Set the title for the second subplot (Profit outliers)
axes[1].set_title("Profit Outliers")

# 🔧 Adjust layout to avoid overlapping elements
plt.tight_layout()

# 🚫 Disable grid lines for both subplots for a cleaner appearance
axes[0].grid(False)
axes[1].grid(False)

# 🖼️ Display the plots
plt.show()

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## **💡 Key Business Insights**

# %% [markdown]
# #### **📌 Top-Selling Categories**

# %%
# 📊 DATA ANALYSIS - TOP CATEGORIES BY REVENUE

# 🔢 Group the data by 'Category' and calculate the total revenue for each category using 'sum()'
# Then, sort the revenue values in descending order to get the top categories
top_cat = df.groupby('Category')['Revenue'].sum().sort_values(ascending=False)

# 📝 Print the sorted total revenue by category to view the top categories
print(top_cat)
# Out:
# Category
# Electronics        27795
# Accessories        11680
# Networking         10004
# Office Supplies     9960
# Name: Revenue, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# #### **📌 High-Profit Products**

# %%
# 📊 DATA ANALYSIS - TOP 10 PRODUCTS BY PROFIT

# 🔢 Group the data by 'Product' and calculate the total profit for each product using 'sum()'
# Then, sort the profit values in descending order to get the top products
# Use 'head(10)' to select the top 10 products with the highest profit
top_profit = df.groupby('Product')['Profit'].sum().sort_values(ascending=False).head(10)

# 📝 Print the top 10 products by total profit
print(top_profit)
# Out:
# Product
# Printer       2228.97
# Monitor       2110.80
# Router        1593.49
# Keyboard      1472.55
# Tablet        1370.83
# Smartphone     902.14
# Mouse          719.49
# Laptop         624.27
# Name: Profit, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# #### **📌 Low/Negative Profit Areas**

# %%
# 📊 DATA ANALYSIS - REGIONS WITH LOWEST PROFIT

# 🔢 Group the data by 'Region' and calculate the total profit for each region using 'sum()'
# Then, sort the profit values in ascending order to get the regions with the lowest profit
low_profit = df.groupby('Region')['Profit'].sum().sort_values()

# 📝 Print the regions with the lowest total profit
print(low_profit)
# Out:
# Region
# Central     780.07
# South      1011.29
# North      2758.31
# West       3206.87
# East       3266.00
# Name: Profit, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# #### **📌 Quantity vs Profit (Are bulk orders profitable?)**

# %%
# 📊 DATA VISUALIZATION - QUANTITY VS PROFIT

# 🖼️ Create a scatter plot to visualize the relationship between 'Quantity' and 'Profit'
# The color of the points is set to red
sns.scatterplot(x='Quantity', y='Profit', data=df, color='red')

# 🏷️ Set the title of the plot to describe what we're visualizing
plt.title("Quantity vs Profit")

# 🚫 Disable grid lines for a cleaner plot
plt.grid(False)

# 🖼️ Display the plot
plt.show()
